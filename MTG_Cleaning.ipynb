# %%
# from mtgsdk import Card
# import pandas as pd
# import json

# Get all cards
# cards = Card.all()

# # Filter Cards
# # You can chain 'where' clauses together. The key of the hash
# # should be the URL parameter you are trying to filter on
# cards = Card.where(supertypes='legendary') \
#             .where(types='creature') \
#             .where(colors='red,white') \
#             .all()

# # Get cards on a specific page / pageSize
# cards = Card.where(page=50).where(pageSize=50).all()

# %%
pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /opt/anaconda3/lib/python3.9/site-packages (10.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /opt/anaconda3/lib/python3.9/site-packages (from pyarrow) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json 
import pandas as pd 
from mtgsdk import Card
import numpy as np

# data_from_file = "/Users/owner/Analysis_Projects/DeckList.json"

# with open(data_from_file) as f:
#     data = json.loads(f.read())
#     my_json_file_working = data["data"]
#     print(my_json_file_working)
        
# MTG_df = pd.read_json(my_json_file_working) 

# data_json = json.loads(data_from_file)
# print(data_json)

# data_from_file.close()

# %%
# df = pd.DataFrame(my_json_file_working)
# df

# %%
import json 
import pandas as pd 
from mtgsdk import Card

data_from_file_two = "/Users/owner/Analysis_Projects/AllIdentifiers.json"

with open(data_from_file_two) as f:
    data = json.loads(f.read())
    my_json_file_working_two = data["data"]
    print(my_json_file_working_two)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df_second= pd.DataFrame(my_json_file_working_two)
df_second
# Out:
#                         00010d56-fe38-5e35-8aed-518019aa36a5  \
# artist                                         Lius Lasahido
# availability                                         [paper]
# borderColor                                            black
# colorIdentity                                            [U]
# colors                                                   [U]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         0001e0d0-2dcd-5640-aadc-a84765cf5fc9  \
# artist                                        Jesper Myrfors
# availability                                         [paper]
# borderColor                                            white
# colorIdentity                                            [R]
# colors                                                   [R]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         0003caab-9ff5-5d1a-bc06-976dd0457f19  \
# artist                                            Drew Baker
# availability                                   [mtgo, paper]
# borderColor                                            black
# colorIdentity                                            [G]
# colors                                                   [G]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         0003d249-25d9-5223-af1e-1130f09622a7  \
# artist                                            Jason Chan
# availability                                   [mtgo, paper]
# borderColor                                            black
# colorIdentity                                         [G, R]
# colors                                                [G, R]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         0004a4fb-92c6-59b2-bdbe-ceb584a9e401  \
# artist                                      Scott M. Fischer
# availability                            [arena, mtgo, paper]
# borderColor                                            black
# colorIdentity                                            [W]
# colors                                                   [W]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         00054115-b2b6-5e22-a694-76fc8639eeb2  \
# artist                                        Tristan Elwell
# availability                                         [paper]
# borderColor                                             gold
# colorIdentity                                            [U]
# colors                                                   [U]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         00059c8d-868a-53ef-a1b0-fcfaabed2570  \
# artist                                          Greg Staples
# availability                                         [paper]
# borderColor                                            black
# colorIdentity                                            [W]
# colors                                                   [W]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         0005d268-3fd0-5424-bc6b-573ecd713aa1  \
# artist                                                  Izzy
# availability                                   [mtgo, paper]
# borderColor                                            black
# colorIdentity                                            [W]
# colors                                                   [W]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         0005f481-f2d4-53fa-ba37-cfcf5a5f87f1  \
# artist                                             Tony Foti
# availability                                   [mtgo, paper]
# borderColor                                            black
# colorIdentity                                            [B]
# colors                                                   [B]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         0005fe8b-170d-5381-baaf-3d6bd58042f8  ...  \
# artist                                      Alexander Mokhov  ...
# availability                                         [paper]  ...
# borderColor                                            black  ...
# colorIdentity                                            [B]  ...
# colors                                                   [B]  ...
# ...                                                      ...  ...
# attractionLights                                         NaN  ...
# hasContentWarning                                        NaN  ...
# hasAlternativeDeckLimit                                  NaN  ...
# faceFlavorName                                           NaN  ...
# cardParts                                                NaN  ...
#
#                         fffa216a-48c1-5b3f-bc25-a9f43fca8568  \
# artist                                      Cristi Balanescu
# availability                                         [arena]
# borderColor                                            black
# colorIdentity                                            [G]
# colors                                                   [G]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         fffa4546-e7ac-5291-b878-2e66ea1b1dfa  \
# artist                                          Aaron Miller
# availability                                   [mtgo, paper]
# borderColor                                            black
# colorIdentity                                            [W]
# colors                                                   [W]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         fffa4ccf-733e-513a-98f9-181b9549de62  \
# artist                                        Christine Choi
# availability                                         [paper]
# borderColor                                            black
# colorIdentity                                             []
# colors                                                    []
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         fffa9242-6444-567c-a45b-da2b45249232  \
# artist                                    Bastien L. Deharme
# availability                                         [paper]
# borderColor                                            black
# colorIdentity                                            [G]
# colors                                                   [G]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         fffb1bae-045f-526a-810e-6a4f7178bb91  \
# artist                                          Lie Setiawan
# availability                                          [mtgo]
# borderColor                                            black
# colorIdentity                                            [R]
# colors                                                   [R]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         fffb659e-b3fa-5cd8-9423-fe5ac74248b5  \
# artist                                             Dan Scott
# availability                                         [paper]
# borderColor                                            black
# colorIdentity                                         [G, R]
# colors                                                [G, R]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         fffbc95a-c4d1-56aa-8653-8a7c71fe19ce  \
# artist                                             Nic Klein
# availability                                   [mtgo, paper]
# borderColor                                            black
# colorIdentity                                             []
# colors                                                    []
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         fffc1305-a118-559b-9504-3d7b56ca0bde  \
# artist                                        Terese Nielsen
# availability                                   [mtgo, paper]
# borderColor                                            black
# colorIdentity                                            [U]
# colors                                                    []
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         fffdd333-3789-5104-a8be-37be199a2cb1  \
# artist                                          Brian Durfee
# availability                                         [paper]
# borderColor                                            black
# colorIdentity                                            [R]
# colors                                                    []
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
#                         fffe10ca-d43b-5234-b768-201cc5c2217e
# artist                                        Richard Thomas
# availability                                         [paper]
# borderColor                                            black
# colorIdentity                                            [U]
# colors                                                   [U]
# ...                                                      ...
# attractionLights                                         NaN
# hasContentWarning                                        NaN
# hasAlternativeDeckLimit                                  NaN
# faceFlavorName                                           NaN
# cardParts                                                NaN
#
# [80 rows x 77728 columns]

# %%
# df_second_transpose = df_second.T.reset_index()
# df_second_transpose.to_feather("second_transposed.feather")
# df_second_transpose

# %%
df_two = pd.read_feather("second_transposed.feather")
df_two
# Out:
#                                       index            artist  \
# 0      00010d56-fe38-5e35-8aed-518019aa36a5     Lius Lasahido
# 1      0001e0d0-2dcd-5640-aadc-a84765cf5fc9    Jesper Myrfors
# 2      0003caab-9ff5-5d1a-bc06-976dd0457f19        Drew Baker
# 3      0003d249-25d9-5223-af1e-1130f09622a7        Jason Chan
# 4      0004a4fb-92c6-59b2-bdbe-ceb584a9e401  Scott M. Fischer
# ...                                     ...               ...
# 77723  fffb659e-b3fa-5cd8-9423-fe5ac74248b5         Dan Scott
# 77724  fffbc95a-c4d1-56aa-8653-8a7c71fe19ce         Nic Klein
# 77725  fffc1305-a118-559b-9504-3d7b56ca0bde    Terese Nielsen
# 77726  fffdd333-3789-5104-a8be-37be199a2cb1      Brian Durfee
# 77727  fffe10ca-d43b-5234-b768-201cc5c2217e    Richard Thomas
#
#                availability borderColor colorIdentity  colors  \
# 0                   [paper]       black           [U]     [U]
# 1                   [paper]       white           [R]     [R]
# 2             [mtgo, paper]       black           [G]     [G]
# 3             [mtgo, paper]       black        [G, R]  [G, R]
# 4      [arena, mtgo, paper]       black           [W]     [W]
# ...                     ...         ...           ...     ...
# 77723               [paper]       black        [G, R]  [G, R]
# 77724         [mtgo, paper]       black            []      []
# 77725         [mtgo, paper]       black           [U]      []
# 77726               [paper]       black           [R]      []
# 77727               [paper]       black           [U]     [U]
#
#        convertedManaCost  edhrecRank         finishes  \
# 0                    7.0      6641.0           [foil]
# 1                    3.0      2700.0        [nonfoil]
# 2                    1.0      8297.0  [nonfoil, foil]
# 3                    5.0     16232.0  [nonfoil, foil]
# 4                    3.0      1376.0  [nonfoil, foil]
# ...                  ...         ...              ...
# 77723                3.0     11619.0        [nonfoil]
# 77724                1.0     11339.0        [nonfoil]
# 77725                0.0         NaN        [nonfoil]
# 77726                0.0         NaN        [nonfoil]
# 77727                1.0      7731.0        [nonfoil]
#
#                                               flavorText  ... colorIndicator  \
# 0      He answers questions as readily as he asks the...  ...           None
# 1      To become king of the Goblins, one must assass...  ...           None
# 2                                                   None  ...           None
# 3                   "May the earth rise up to meet you."  ...           None
# 4      The law is meant to ensure that people kill ea...  ...           None
# ...                                                  ...  ...            ...
# 77723  Gruul shamans are bent on punishing the civili...  ...           None
# 77724                                               None  ...           None
# 77725                                               None  ...           None
# 77726                                               None  ...           None
# 77727                                               None  ...           None
#
#        hand  life  isStorySpotlight flavorName attractionLights  \
# 0      None  None              None       None             None
# 1      None  None              None       None             None
# 2      None  None              None       None             None
# 3      None  None              None       None             None
# 4      None  None              None       None             None
# ...     ...   ...               ...        ...              ...
# 77723  None  None              None       None             None
# 77724  None  None              None       None             None
# 77725  None  None              None       None             None
# 77726  None  None              None       None             None
# 77727  None  None              None       None             None
#
#       hasContentWarning hasAlternativeDeckLimit faceFlavorName cardParts
# 0                  None                    None           None      None
# 1                  None                    None           None      None
# 2                  None                    None           None      None
# 3                  None                    None           None      None
# 4                  None                    None           None      None
# ...                 ...                     ...            ...       ...
# 77723              None                    None           None      None
# 77724              None                    None           None      None
# 77725              None                    None           None      None
# 77726              None                    None           None      None
# 77727              None                    None           None      None
#
# [77728 rows x 81 columns]

# %%
df_two.columns
# Out:
# Index(['index', 'artist', 'availability', 'borderColor', 'colorIdentity',
#        'colors', 'convertedManaCost', 'edhrecRank', 'finishes', 'flavorText',
#        'foreignData', 'frameVersion', 'hasFoil', 'hasNonFoil', 'identifiers',
#        'isPromo', 'isReprint', 'isStarter', 'keywords', 'language', 'layout',
#        'legalities', 'manaCost', 'manaValue', 'name', 'number', 'power',
#        'printings', 'promoTypes', 'purchaseUrls', 'rarity', 'rulings',
#        'securityStamp', 'setCode', 'subtypes', 'supertypes', 'text',
#        'toughness', 'type', 'types', 'uuid', 'boosterTypes', 'originalText',
#        'originalType', 'signature', 'originalReleaseDate', 'variations',
#        'isOnlineOnly', 'isReserved', 'frameEffects', 'faceConvertedManaCost',
#        'faceManaValue', 'faceName', 'leadershipSkills', 'otherFaceIds', 'side',
#        'isOversized', 'reverseRelated', 'duelDeck', 'isTextless',
#        'relatedCards', 'watermark', 'loyalty', 'isAlternative', 'isFunny',
#        'isFullArt', 'isTimeshifted', 'rebalancedPrintings', 'asciiName',
#        'isRebalanced', 'originalPrintings', 'colorIndicator', 'hand', 'life',
#        'isStorySpotlight', 'flavorName', 'attractionLights',
#        'hasContentWarning', 'hasAlternativeDeckLimit', 'faceFlavorName',
#        'cardParts'],
#       dtype='object')

# %%
df_three = df_two.drop(columns = ['index', 'artist', 'availability', 'borderColor',
       'colors', 'convertedManaCost', 'edhrecRank', 'finishes', 'flavorText',
       'foreignData', 'frameVersion', 'hasFoil', 'hasNonFoil', 'identifiers',
       'isPromo', 'isReprint', 'isStarter', 'keywords', 'language', 'layout',
       'legalities', 'manaCost','number',
       'printings', 'promoTypes', 'purchaseUrls', 'rarity', 'rulings',
       'securityStamp', 'setCode', 'subtypes', 'supertypes', 'text','uuid', 'boosterTypes', 'originalText',
       'originalType', 'signature', 'originalReleaseDate', 'variations',
       'isOnlineOnly', 'isReserved', 'frameEffects', 'faceConvertedManaCost',
       'faceManaValue', 'faceName', 'leadershipSkills', 'otherFaceIds', 'side',
       'isOversized', 'reverseRelated', 'duelDeck', 'isTextless',
       'relatedCards', 'watermark', 'loyalty', 'isAlternative', 'isFunny',
       'isFullArt', 'isTimeshifted', 'rebalancedPrintings', 'asciiName',
       'isRebalanced', 'originalPrintings', 'colorIndicator', 'hand', 'life',
       'isStorySpotlight', 'flavorName', 'attractionLights',
       'hasContentWarning', 'hasAlternativeDeckLimit', 'faceFlavorName',
       'cardParts'])

# %%
df_three.duplicated("name", keep= "first")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 77723     True
# 77724     True
# 77725     True
# 77726     True
# 77727     True
# Length: 77728, dtype: bool

# %%
df_three.drop_duplicates("name", keep="first", inplace=True)
df_three
# Out:
#       colorIdentity  manaValue                      name power toughness  \
# 0               [U]        7.0  Sphinx of the Final Word     5         5
# 1               [R]        3.0               Goblin King     2         2
# 2               [G]        1.0             Caravan Vigil  None      None
# 3            [G, R]        5.0         Deadshot Minotaur     3         4
# 4               [W]        3.0               Rule of Law  None      None
# ...             ...        ...                       ...   ...       ...
# 77661           [B]        5.0               Plague Dogs     3         3
# 77674           [R]        3.0          Traitorous Blood  None      None
# 77705            []        7.0           Aether Searcher     6         4
# 77717            []        3.0          Network Terminal  None      None
# 77719           [W]        3.0   Companion of the Trials     2         2
#
#                                   type                 types
# 0                    Creature — Sphinx            [Creature]
# 1                    Creature — Goblin            [Creature]
# 2                              Sorcery             [Sorcery]
# 3                  Creature — Minotaur            [Creature]
# 4                          Enchantment         [Enchantment]
# ...                                ...                   ...
# 77661  Creature — Phyrexian Zombie Dog            [Creature]
# 77674                          Sorcery             [Sorcery]
# 77705    Artifact Creature — Construct  [Artifact, Creature]
# 77717                         Artifact            [Artifact]
# 77719          Creature — Bird Soldier            [Creature]
#
# [27079 rows x 7 columns]

# %%
df = df_three[["colorIdentity", "manaValue", "power", "toughness", "types"]]

# %%
df.head()
df.to_csv("df.csv", index=False)

# %%
df_three["colorIdentity"].value_counts()
# Out:
# [B]          3916
# [W]          3850
# [R]          3834
# [U]          3816
# [G]          3765
#              ...
# []              1
# [B, G, R]       1
# []              1
# []              1
# []              1
# Name: colorIdentity, Length: 7903, dtype: int64

# %%
color_lists_df = df_three[["colorIdentity"]]
mana_value_df = df_three[["manaValue"]]
creatures_df = df_three[["types"]]


color_lists_df.to_csv("color_lists.csv")
color_lists_df
# Out:
#       colorIdentity
# 0               [U]
# 1               [R]
# 2               [G]
# 3            [G, R]
# 4               [W]
# ...             ...
# 77661           [B]
# 77674           [R]
# 77705            []
# 77717            []
# 77719           [W]
#
# [27079 rows x 1 columns]

# %%
color_lists_df.set_index()

# %%
color_lists_df = pd.read_csv("color_lists.csv")

color_lists_df
# Out:
#        Unnamed: 0 colorIdentity  U  R  G  W  B   None
# 0               0             U  1  0  0  0   0     0
# 1               1             R  0  1  0  0   0     0
# 2               2             G  0  0  1  0   0     0
# 3               3            GR  0  1  1  0   0     0
# 4               4             W  0  0  0  1   0     0
# ...           ...           ... .. .. .. ..  ..   ...
# 27074       77661             B  0  0  0  0   1     0
# 27075       77674             R  0  1  0  0   0     0
# 27076       77705           NaN  0  0  0  0   0     1
# 27077       77717           NaN  0  0  0  0   0     1
# 27078       77719             W  0  0  0  1   0     0
#
# [27079 rows x 8 columns]

# %%
from sklearn.cluster import KMeans
from sklearn import preprocessing
import sklearn.cluster as cluster
import sklearn.metrics as metrics
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Try Logistic Regreesion for U Cards 

y = color_lists_df["U"]
X = color_lists_df.drop(columns = ["colorIdentity","U"])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

classifier = LogisticRegression(solver='lbfgs', max_iter=200, random_state=1)

classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7926144756277695

# %%
# Try Logistic Regreesion for R Cards 

y = color_lists_df["R"]
X = color_lists_df.drop(columns = ["colorIdentity","R"])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

classifier = LogisticRegression(solver='lbfgs', max_iter=200, random_state=1)

classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7911373707533235

# %%
# Try Logistic Regreesion for R Cards 

y = color_lists_df["G"]
X = color_lists_df.drop(columns = ["colorIdentity","G"])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

classifier = LogisticRegression(solver='lbfgs', max_iter=200, random_state=1)

classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7952732644017725

# %%
# Perform K-means algorithm 
# X = color_lists_df[["U", "R", "G", "W", "B"]]

# km = KMeans(n_clusters = 3)
# km.fit(X)
# y_kmeans = km.predict(X)
# y_keans
